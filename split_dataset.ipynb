# %%
import pandas as pd

# %%
df = pd.read_csv('data/e_commerce_shopper_behaviour_and_lifestyle.csv')

# %%
col1 = [
    'user_id', 'age', 'gender', 'country', 'urban_rural', 'income_level',
    'employment_status', 'education_level', 'relationship_status',
    'has_children', 'household_size', 'occupation', 'ethnicity',
    'language_preference', 'device_type'
]

# %%
col2 = ['user_id', 'weekly_purchases', 'monthly_spend', 'cart_abandonment_rate',
    'review_writing_frequency', 'average_order_value', 'preferred_payment_method',
    'coupon_usage_frequency', 'loyalty_program_member', 'referral_count',
    'product_category_preference', 'shopping_time_of_day', 'weekend_shopper',
    'impulse_purchases_per_month', 'browse_to_buy_ratio', 'return_frequency',
    'budgeting_style', 'brand_loyalty_score', 'impulse_buying_score',
    'environmental_consciousness', 'health_conscious_shopping', 'travel_frequency',
    'hobby_count', 'social_media_influence_score', 'reading_habits', 'exercise_frequency',
    'stress_from_financial_decisions', 'overall_stress_level', 'sleep_quality',
    'physical_activity_level', 'mental_health_score', 'daily_session_time_minutes',
    'product_views_per_day', 'ad_views_per_day', 'ad_clicks_per_day',
    'wishlist_items_count', 'cart_items_average', 'checkout_abandonments_per_month',
    'purchase_conversion_rate', 'app_usage_frequency', 'notification_response_rate',
    'account_age_months', 'last_purchase_date', 'social_sharing_frequency',
    'premium_subscription', 'return_rate']

# %%
df[col1].to_csv('data/user_demographics.csv', index=False)

# %%
df[col2].to_csv('data/user_shopping_behavior.csv', index=False)

# %%
shopping_behavior_df = pd.read_csv('data/user_shopping_behavior.csv')

# %%
shopping_behavior_df
# Out:
#         user_id  weekly_purchases  monthly_spend  cart_abandonment_rate  \
# 0             1                 4           2405                      0
# 1             2                13           3651                     28
# 2             3                10           2045                     14
# 3             4                16           1611                     11
# 4             5                17           3476                     57
# ...         ...               ...            ...                    ...
# 999995   999996                15            279                     83
# 999996   999997                10            773                     25
# 999997   999998                11            387                     50
# 999998   999999                 1            114                     41
# 999999  1000000                 5            392                      0
#
#         review_writing_frequency  average_order_value  \
# 0                              3                  445
# 1                              6                  179
# 2                              1                   26
# 3                              2                  403
# 4                              3                   68
# ...                          ...                  ...
# 999995                         3                  374
# 999996                         4                  156
# 999997                         4                  156
# 999998                         1                  269
# 999999                         2                  261
#
#        preferred_payment_method  coupon_usage_frequency  \
# 0                        PayPal                       3
# 1                    Google Pay                       0
# 2                        PayPal                       0
# 3                   Credit Card                       2
# 4                     Apple Pay                       0
# ...                         ...                     ...
# 999995               Google Pay                       4
# 999996               Debit Card                       2
# 999997              Credit Card                       3
# 999998                Apple Pay                       2
# 999999              Credit Card                       4
#
#         loyalty_program_member  referral_count  ... cart_items_average  \
# 0                            1               8  ...                 10
# 1                            1               3  ...                  5
# 2                            0              10  ...                  3
# 3                            1               0  ...                  5
# 4                            1               0  ...                  8
# ...                        ...             ...  ...                ...
# 999995                       0               3  ...                  4
# 999996                       1               0  ...                 10
# 999997                       0               2  ...                  6
# 999998                       1               8  ...                  4
# 999999                       1               9  ...                 10
#
#        checkout_abandonments_per_month  purchase_conversion_rate  \
# 0                                    2                        62
# 1                                    7                        54
# 2                                    3                        33
# 3                                    9                        26
# 4                                    0                        18
# ...                                ...                       ...
# 999995                               3                        26
# 999996                               9                        31
# 999997                               5                        19
# 999998                               2                        56
# 999999                              10                        79
#
#         app_usage_frequency  notification_response_rate  account_age_months  \
# 0                         7                          74                  19
# 1                         5                          23                   8
# 2                         7                          12                  13
# 3                         4                          19                   9
# 4                         7                          30                   3
# ...                     ...                         ...                 ...
# 999995                    2                          50                  21
# 999996                    5                          78                  15
# 999997                    7                           8                  16
# 999998                    5                           8                  11
# 999999                    0                          64                   1
#
#        last_purchase_date  social_sharing_frequency  premium_subscription  \
# 0              2025-06-22                         6                     1
# 1              2026-07-25                         3                     0
# 2              2026-02-26                         6                     0
# 3              2026-10-27                         7                     0
# 4              2026-06-23                         3                     0
# ...                   ...                       ...                   ...
# 999995         2025-06-27                         2                     1
# 999996         2025-06-05                         7                     1
# 999997         2026-09-25                         5                     0
# 999998         2026-10-25                         2                     0
# 999999         2025-12-17                         5                     0
#
#         return_rate
# 0                50
# 1                37
# 2                53
# 3                98
# 4                86
# ...             ...
# 999995           93
# 999996           97
# 999997           96
# 999998           46
# 999999           43
#
# [1000000 rows x 46 columns]
